# %%
import pandas as pd
pd.set_option('display.max_rows',None)

# %%
data1 = pd.read_csv('../data/summary_crawling/modify_keyword/4-1_01-18.csv')
data2 = pd.read_csv('../data/summary_crawling/modify_keyword/4-1_20-31.csv')
data3 = pd.read_csv('../data/summary_crawling/modify_keyword/4-2_01-14.csv')
data4 = pd.read_csv('../data/summary_crawling/modify_keyword/4-2_16-29.csv')

# %%
combined_df = pd.concat([data1,data2,data3,data4],ignore_index=True)
combined_df.info()
combined_df.to_csv('combined_keyword.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   강의 제목   51 non-null     object
#  1   수업 내용   51 non-null     object
#  2   요약      51 non-null     object
#  3   키워드     51 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
combined_df
# Out:
#                  강의 제목                                              수업 내용  \
# 0          01강 큰 수 (1)  만에 대해 알아봅니다. 1은 수모형으로 나타내면 작은 수입니다. 10은 1이 10개...
# 1          02강 큰 수 (2)  이번 시간에는 10만, 100만, 1000만에 대해서 알아봅니다. 만은 1 뒤에 0...
# 2          03강 큰 수 (3)  이번 수업에서는 억과 조에 대해 알아봅니다. 천만이 10개인 수는 1억으로 나타내며...
# 3          04강 큰 수 (4)  지난 시간에 억과 조에 대해 배웠습니다. 이번 시간에는 수의 뛰어 세기와 수의 크기...
# 4           06강 각도 (1)  이번 시간에는 각도에 대해 배웁니다. 각은 한 점에서 그은 두 반직선으로 이루어진 ...
# 5           07강 각도 (2)  이번 시간에는 각을 직접 그리는 방법을 배웁니다. 각도기와 자를 이용하여 70도인 ...
# 6           08강 각도 (3)  지난 시간에 각을 그리고 각의 종류에 대해 배웠습니다. 이번 시간에는 각도의 합과 ...
# 7           09강 각도 (4)  삼각형의 세 각의 크기의 합에 대해 알아봅니다. 삼각형을 세 조각으로 잘라서 세 꼭...
# 8           10강 각도 (5)  지난 시간에 삼각형의 세 각의 크기의 합에 대해 배웠습니다. 이번 시간에는 사각형의...
# 9      12강 곱셈과 나눗셈 (1)  세 자릿수 곱하기 몇십의 계산 방법을 배웁니다. 예를 들어, 172 곱하기 4는 6...
# 10     13강 곱셈과 나눗셈 (2)  이번 시간에는 세 자릿수 곱하기 두 자릿수를 계산하는 방법에 대해 배워보겠습니다. ...
# 11     14강 곱셈과 나눗셈 (3)  이번 시간에는 나눗셈을 배웁니다. 나눗셈의 의미를 이해하기 위해 구슬을 예로 들어 ...
# ...

# %%
t_df1 = pd.read_csv('강의_키워드_썸네일_데이터_4-1.csv')
t_df2 = pd.read_csv('강의_키워드_썸네일_데이터_4-2.csv')
combined_df_thumb = pd.concat([t_df1,t_df2],ignore_index=True)
combined_df_thumb.to_csv('combined_thumbnail.csv',index=False)

# %%
combined_df_thumb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   강의 제목    64 non-null     object
#  1   수업 내용    64 non-null     object
#  2   키워드      64 non-null     object
#  3   썸네일 URL  64 non-null     object
# dtypes: object(4)
# memory usage: 2.1+ KB

# %%
# CSV 파일 읽기
df_keyword = pd.read_csv('combined_keyword.csv')  # 데이터 51개
df_thumbnail = pd.read_csv('combined_thumbnail.csv')  # 데이터 66개

# 병합 전에 중복을 제거 (강의 제목 기준)
# df_thumbnail_clean = df_thumbnail.drop_duplicates(subset='강의 제목', keep='first')

# %%
df_keyword.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   강의 제목   51 non-null     object
#  1   수업 내용   51 non-null     object
#  2   요약      51 non-null     object
#  3   키워드     51 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
df_thumbnail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   강의 제목    64 non-null     object
#  1   수업 내용    64 non-null     object
#  2   키워드      64 non-null     object
#  3   썸네일 URL  64 non-null     object
# dtypes: object(4)
# memory usage: 2.1+ KB

# %%
df_combined = pd.merge(df_keyword, df_thumbnail[['강의 제목', '썸네일 URL']], on='강의 제목', how='left')

# %%
df_combined['강의 학기'] = '만점왕 수학 4-1 (2024)'

# %%
df_combined.iloc[26:,-1:] = '만점왕 수학 4-2 (2024)'

# %%
df_combined
# Out:
#                  강의 제목                                              수업 내용  \
# 0          01강 큰 수 (1)  만에 대해 알아봅니다. 1은 수모형으로 나타내면 작은 수입니다. 10은 1이 10개...
# 1          02강 큰 수 (2)  이번 시간에는 10만, 100만, 1000만에 대해서 알아봅니다. 만은 1 뒤에 0...
# 2          03강 큰 수 (3)  이번 수업에서는 억과 조에 대해 알아봅니다. 천만이 10개인 수는 1억으로 나타내며...
# 3          04강 큰 수 (4)  지난 시간에 억과 조에 대해 배웠습니다. 이번 시간에는 수의 뛰어 세기와 수의 크기...
# 4           06강 각도 (1)  이번 시간에는 각도에 대해 배웁니다. 각은 한 점에서 그은 두 반직선으로 이루어진 ...
# 5           07강 각도 (2)  이번 시간에는 각을 직접 그리는 방법을 배웁니다. 각도기와 자를 이용하여 70도인 ...
# 6           08강 각도 (3)  지난 시간에 각을 그리고 각의 종류에 대해 배웠습니다. 이번 시간에는 각도의 합과 ...
# 7           09강 각도 (4)  삼각형의 세 각의 크기의 합에 대해 알아봅니다. 삼각형을 세 조각으로 잘라서 세 꼭...
# 8           10강 각도 (5)  지난 시간에 삼각형의 세 각의 크기의 합에 대해 배웠습니다. 이번 시간에는 사각형의...
# 9      12강 곱셈과 나눗셈 (1)  세 자릿수 곱하기 몇십의 계산 방법을 배웁니다. 예를 들어, 172 곱하기 4는 6...
# 10     13강 곱셈과 나눗셈 (2)  이번 시간에는 세 자릿수 곱하기 두 자릿수를 계산하는 방법에 대해 배워보겠습니다. ...
# 11     14강 곱셈과 나눗셈 (3)  이번 시간에는 나눗셈을 배웁니다. 나눗셈의 의미를 이해하기 위해 구슬을 예로 들어 ...
# ...

# %%
df_combined.rename(columns={'수업 내용':'강의 내용'},inplace=True)

# %%
df_combined.to_csv('final_data.csv',index=False)
